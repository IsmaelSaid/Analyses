# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = "Demandeurs d’emploi inscrits en fin de mois à Pôle emploi par Niveau de formation - Région _ La Réun.csv"
data = pd.read_csv(filename,skiprows=3,sep=";",skipfooter=1,engine='python')
data["Mois"] = pd.date_range(start="1-1996",end="1-2023",freq="M",name= "Mois")
data = data.iloc[263:]
data.iloc[:,1:9] = data.iloc[:,1:9].applymap(lambda x : x.replace(" ","")).astype("int64")

data.to_csv("data_par_formation.csv",index=False)
# Out:
# /tmp/ipykernel_319464/2275707837.py:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data.iloc[:,1:9] = data.iloc[:,1:9].applymap(lambda x : x.replace(" ","")).astype("int64")

# %%
fig, ax = plt.subplots()
sns.set_style("whitegrid")
data.iloc[:,[0,2,3,4,5]].plot(ax = ax , x = "Mois")
ax.set_title("Evolution du nombre d'inscrits à pôle emploi")
ax.set_xlabel("Année")
ax.set_ylabel("Nombre d'inscrits")
plt.show()

fig.savefig("par_diplôme")
